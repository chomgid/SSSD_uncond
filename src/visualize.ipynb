# %%
import torch
import pandas as pd
import numpy as np
import pickle
import matplotlib.pyplot as plt
# Out:
# /tmp/ipykernel_3615986/2832691642.py:2: DeprecationWarning:
# Pyarrow will become a required dependency of pandas in the next major release of pandas (pandas 3.0),
# (to allow more performant data types, such as the Arrow string type, and better interoperability with other libraries)
# but was not found to be installed on your system.
# If this would cause problems for you,
# please provide us feedback at https://github.com/pandas-dev/pandas/issues/54466
#
#   import pandas as pd

# %%
gen_data = np.load('./results/ch256_T200_betaT0.02/generated_samples.npy')

# %%
gen_data.shape
# Out:
# (400, 12, 1000)

# %%
plt.plot(gen_data[2,0,:])

# %%
with open('/home/chomgid14/TSdata/PTB_train_1000.pkl', 'rb') as tf:
    data = pickle.load(tf)

# %%
data.shape
# Out:
# (17441, 12, 1000)

# %%
plt.plot(data[3,0,:])

# %%
fig, axs = plt.subplots(3, 3, figsize=(30, 15))
axs[0, 0].plot(data[0,0,:],'tab:blue')
axs[0, 1].set_title('Real')
axs[1, 0].plot(data[1,0,:],'tab:blue')
axs[2, 0].plot(data[2,0,:],'tab:blue')
axs[0, 1].plot(data[3,0,:],'tab:blue')
axs[1, 1].plot(data[4,0,:],'tab:blue')
axs[2, 1].plot(data[5,0,:],'tab:blue')
axs[0, 2].plot(data[6,0,:],'tab:blue')
axs[1, 2].plot(data[7,0,:],'tab:blue')
axs[2, 2].plot(data[8,0,:],'tab:blue')

# %%
fig, axs = plt.subplots(3, 3, figsize=(30, 15))
axs[0, 0].plot(gen_data[0,0,:],'tab:green')
axs[0, 1].set_title('Synthetic')
axs[1, 0].plot(gen_data[1,0,:],'tab:green')
axs[2, 0].plot(gen_data[2,0,:],'tab:green')
axs[0, 1].plot(gen_data[3,0,:],'tab:green')
axs[1, 1].plot(gen_data[4,0,:],'tab:green')
axs[2, 1].plot(gen_data[5,0,:],'tab:green')
axs[0, 2].plot(gen_data[6,0,:],'tab:green')
axs[1, 2].plot(gen_data[7,0,:],'tab:green')
axs[2, 2].plot(gen_data[8,0,:],'tab:green')
